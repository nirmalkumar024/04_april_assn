# %% [markdown]
# Q1. Describe the decision tree classifier algorithm and how it works to make predictions.

# %% [markdown]
# In the decision tree classifier use the itretre the data based on the thier responsed and one which have leaf node then it is close, and onther one itretre in to their responsed and going on till leaf node not achived.

# %% [markdown]
# Q2. Provide a step-by-step explanation of the mathematical intuition behind decision tree classification.

# %% [markdown]
# The step of making decision trees are following:-
# step1:- take the outlook or header
# step2:-itetret in to desire factores
# step3:- itetret factors in to binary factor(yes/no)
# step4:-itetret till factors become leaf node.

# %% [markdown]
# Q3. Explain how a decision tree classifier can be used to solve a binary classification problem.

# %% [markdown]
# In binary classification we have need only two outcome (yes/no), and as well in decision tree their have out come and it is itrete into two parts till achived leaf node.

# %% [raw]
# Q4. Discuss the geometric intuition behind decision tree classification and how it can be used to make
# predictions.

# %% [markdown]
# In geometric of intuition prediction of decision tree classification in this way,there are several rule we can pridict the dicision tree length, types are:-
# 1.Entropy
# 2.Gini Impurity
# These two ways we find the pridiction of the geometric of decision tree

# %% [markdown]
# Q5. Define the confusion matrix and describe how it can be used to evaluate the performance of a
# classification model.

# %% [markdown]
# A confusion matrix is a table that is used to define the performance of a classification algorithm,it is used  to  visualizes and summarizes the performance of a classification algorithm.
# Examples it is help to show the accuracy of data and classification the reports.

# %% [markdown]
# Q6. Provide an example of a confusion matrix and explain how precision, recall, and F1 score can be calculated from it.

# %%
#example of confusion matrix with code and visualization

import matplotlib.pyplot as plt
import numpy
from sklearn import metrics

actual = numpy.random.binomial(1,.9,size = 1000)
predicted = numpy.random.binomial(1,.9,size = 1000)

confusion_matrix = metrics.confusion_matrix(actual, predicted)

cm_display = metrics.ConfusionMatrixDisplay(confusion_matrix = confusion_matrix, display_labels = [False, True])

cm_display.plot()
plt.show()

# %% [markdown]
# Q7. Discuss the importance of choosing an appropriate evaluation metric for a classification problem and explain how this can be done.

# %% [markdown]
# An evaluation metric can be defined as a function that takes an ordered vector of relevance values, and returns a single numeric score, that summarizes those values.
# Evaluation metrics are used to measure the quality of the statistical or machine learning model. Evaluating machine learning models or algorithms is essential for any project.

# %% [markdown]
# Q8.Provide an example of a classification problem where precision is the most important metric, and explain why.

# %% [markdown]
# Metrics are used to monitor and measure the performance of a model (during training and testing), and don't need to be differentiable. However, if, for some tasks, the metric, it can also be used as a loss function (perhaps with some regularizations added to it), it is used to find MSE.

# %%
#Example of code:-

import matplotlib.pyplot as plt
import numpy
from sklearn import metrics

actual = numpy.random.binomial(1,.9,size = 1000)
predicted = numpy.random.binomial(1,.9,size = 1000)

confusion_matrix = metrics.confusion_matrix(actual, predicted)

cm_display = metrics.ConfusionMatrixDisplay(confusion_matrix = confusion_matrix, display_labels = [False, True])

cm_display.plot()
plt.show()

# %% [markdown]
# Q9.Provide an example of a classification problem where recall is the most important metric, and explain why.

# %% [markdown]
# Simply put a classification metric is a number that measures the performance that your machine learning model when it comes to assigning observations to certain classes. Binary classification is a particular situation where you just have to classes:-
# 1.positive.
# 2.negative.
#
# The technical definition of recall is the number of true positives divided by the number of true positives plus the number of false negatives,we know that Recall shall be the model metric we use to select our best model when there is a high cost associated with False Negative.
